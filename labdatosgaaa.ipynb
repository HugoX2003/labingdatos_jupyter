# %% [markdown]
# # **Ing. Datos | Hugo Elias Márquez Diestra**

# %%
# Iniciar siempre
import pandas as pd

# %%
# Iniciar siempre x2
df = pd.read_csv("data/Empleado.csv")

# %%
df
# Out:
#       Edad Renuncia     ViajesNegocios  TarifaDiaria            Departamento  \
# 0       41      Yes      Travel_Rarely          1102                   Sales
# 1       49       No  Travel_Frequently           279  Research & Development
# 2       37      Yes      Travel_Rarely          1373  Research & Development
# 3       33       No  Travel_Frequently          1392  Research & Development
# 4       37      Yes      Travel_Rarely          1373                     NaN
# ...    ...      ...                ...           ...                     ...
# 1480    47       No         Non-Travel          1162  Research & Development
# 1481    35       No                NaN          1490  Research & Development
# 1482    22       No                NaN           581  Research & Development
# 1483    35       No                NaN          1395  Research & Development
# 1484    33       No                NaN           501  Research & Development
#
# ...

# %% [markdown]
# #### Método tail() | Devuelve las ultimas filas del DataFrame

# %%
df.tail(3)
# Out:
#       Edad Renuncia ViajesNegocios  TarifaDiaria            Departamento  \
# 1482    22       No            NaN           581  Research & Development
# 1483    35       No            NaN          1395  Research & Development
# 1484    33       No            NaN           501  Research & Development
#
#       DistanciaDesdeCasa  NivelEducacion      Profesion  RecuentoEmpleados  \
# 1482                 1.0               2  Life Sciences                1.0
# 1483                 9.0               4        Medical                1.0
# 1484                 NaN               2        Medical                1.0
#
#       NumeroEmpleado  ...  SatisfaccionRelacionLaboral HorasEstandar  \
# 1482            2007  ...                            4            80
# 1483            2008  ...                            2            80
# 1484            2009  ...                            1            80
#
#       NivelParticipacionAcciones  AñosLaboralesTotales  \
# ...

# %% [markdown]
# #### Método sample() | Muestra valores aleatorios del DataFrame

# %%
df.sample()
# Out:
#      Edad Renuncia ViajesNegocios  TarifaDiaria Departamento  \
# 125    31      Yes  Travel_Rarely           249        Sales
#
#      DistanciaDesdeCasa  NivelEducacion      Profesion  RecuentoEmpleados  \
# 125                 6.0               4  Life Sciences                1.0
#
#      NumeroEmpleado  ...  SatisfaccionRelacionLaboral HorasEstandar  \
# 125             163  ...                            2            80
#
#      NivelParticipacionAcciones  AñosLaboralesTotales  \
# 125                           0                    12
#
#      NroCapacitacionUltimoAño EquilibrioVidaLaboral  AñosEmpresa  \
# 125                         3                     2            7
#
#     AñosRolActual  AñosDesdeUltimaPromocion  AñosComoJefe
# 125           7.0                       7.0             7
#
# [1 rows x 35 columns]

# %%
df.sample(5)
# Out:
#       Edad Renuncia     ViajesNegocios  TarifaDiaria            Departamento  \
# 1233    35       No      Travel_Rarely          1370  Research & Development
# 1445    56      Yes      Travel_Rarely           310  Research & Development
# 1432    32       No      Travel_Rarely           801                   Sales
# 442     42       No  Travel_Frequently          1474  Research & Development
# 197     35       No  Travel_Frequently           138  Research & Development
#
#       DistanciaDesdeCasa  NivelEducacion         Profesion  RecuentoEmpleados  \
# 1233                27.0               4     Life Sciences                1.0
# 1445                 7.0               2  Technical Degree                1.0
# 1432                 1.0               4         Marketing                1.0
# 442                  5.0               2             Other                1.0
# 197                  2.0               3           Medical                1.0
#
# ...

# %% [markdown]
# #### Método info() | Muestra los nombres de las columnas, los tipo de datos y si tiene valores faltantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Edad                         1485 non-null   int64
#  1   Renuncia                     1484 non-null   object
#  2   ViajesNegocios               1477 non-null   object
#  3   TarifaDiaria                 1485 non-null   int64
#  4   Departamento                 1484 non-null   object
#  5   DistanciaDesdeCasa           1476 non-null   float64
#  6   NivelEducacion               1485 non-null   int64
#  7   Profesion                    1480 non-null   object
#  8   RecuentoEmpleados            1484 non-null   float64
#  9   NumeroEmpleado               1485 non-null   int64
#  10  SatisfaccionAmbienteTrabajo  1485 non-null   int64
#  11  Genero                       1478 non-null   object
#  12  TarifaPorHora                1485 non-null   int64
# ...

# %% [markdown]
# #### Método describe() | Calcula algunas estadisticas de resumen para las columnas numéricas, como la media, el valor máximo, el mínimo

# %%
df.describe()
# Out:
#               Edad  TarifaDiaria  DistanciaDesdeCasa  NivelEducacion  \
# count  1485.000000   1485.000000         1476.000000     1485.000000
# mean     36.907071    803.634343            9.155149        2.913131
# std       9.118610    404.015552            8.088220        1.025876
# min      18.000000    102.000000            1.000000        1.000000
# 25%      30.000000    466.000000            2.000000        2.000000
# 50%      36.000000    802.000000            7.000000        3.000000
# 75%      43.000000   1162.000000           14.000000        4.000000
# max      60.000000   1499.000000           29.000000        5.000000
#
#        RecuentoEmpleados  NumeroEmpleado  SatisfaccionAmbienteTrabajo  \
# count             1484.0     1485.000000                  1485.000000
# mean                 1.0     1028.290236                     2.724579
# std                  0.0      606.830796                     1.092227
# ...

# %% [markdown]
# #### Atributo shape | Atributo que devuelve el número de filas y columnas

# %%
df.shape
# Out:
# (1485, 35)

# %% [markdown]
# #### Atributo columns | Devuelve el nombre de las columnas

# %%
df.columns
# Out:
# Index(['Edad', 'Renuncia', 'ViajesNegocios', 'TarifaDiaria', 'Departamento',
#        'DistanciaDesdeCasa', 'NivelEducacion', 'Profesion',
#        'RecuentoEmpleados', 'NumeroEmpleado', 'SatisfaccionAmbienteTrabajo',
#        'Genero', 'TarifaPorHora', 'ParticipacionTrabajo', 'NivelTrabajo',
#        'RolTrabajador', 'Satisfaccionlaboral', 'EstadoCivil',
#        'IngresosMensuales', 'TarifaMensual', 'NumeroEmpresasTrabajo',
#        'MayorDe18', 'TiempoExtra', 'PorcentajeAumentoSalarial',
#        'CalificacionRendimiento', 'SatisfaccionRelacionLaboral',
#        'HorasEstandar', 'NivelParticipacionAcciones', 'AñosLaboralesTotales',
#        'NroCapacitacionUltimoAño', 'EquilibrioVidaLaboral', 'AñosEmpresa',
#        'AñosRolActual', 'AñosDesdeUltimaPromocion', 'AñosComoJefe'],
#       dtype='object')

# %% [markdown]
# #### Atributo index | Devuelve el indice de las filas ya sea números o nombres de las filas

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1485, step=1)

# %% [markdown]
# #### Atributo values | Devuelve una matriz bidimensional (Numpy 2D) de los valores

# %%
df.values
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4.0, 0.0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7.0, 1.0, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0.0, 0.0, 0],
#        ...,
#        [22, 'No', nan, ..., 2.0, 1.0, 2],
#        [35, 'No', nan, ..., nan, 0.0, 8],
#        [33, 'No', nan, ..., 7.0, 8.0, 1]], dtype=object)

# %% [markdown]
# #### Método to_numpy | Se utiliza para convertir un DataFrame en un arreglo NumPy

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of       Edad Renuncia     ViajesNegocios  TarifaDiaria            Departamento  \
# 0       41      Yes      Travel_Rarely          1102                   Sales
# 1       49       No  Travel_Frequently           279  Research & Development
# 2       37      Yes      Travel_Rarely          1373  Research & Development
# 3       33       No  Travel_Frequently          1392  Research & Development
# 4       37      Yes      Travel_Rarely          1373                     NaN
# ...    ...      ...                ...           ...                     ...
# 1480    47       No         Non-Travel          1162  Research & Development
# 1481    35       No                NaN          1490  Research & Development
# 1482    22       No                NaN           581  Research & Development
# 1483    35       No                NaN          1395  Research & Development
# 1484    33       No                NaN           501  Research & Development
#
# ...

# %% [markdown]
# ## Valores Nulos

# %% [markdown]
# #### Método isNull()

# %%
df.isnull()
# Out:
#        Edad  Renuncia  ViajesNegocios  TarifaDiaria  Departamento  \
# 0     False     False           False         False         False
# 1     False     False           False         False         False
# 2     False     False           False         False         False
# 3     False     False           False         False         False
# 4     False     False           False         False          True
# ...     ...       ...             ...           ...           ...
# 1480  False     False           False         False         False
# 1481  False     False            True         False         False
# 1482  False     False            True         False         False
# 1483  False     False            True         False         False
# 1484  False     False            True         False         False
#
#       DistanciaDesdeCasa  NivelEducacion  Profesion  RecuentoEmpleados  \
# 0                  False           False      False              False
# ...

# %% [markdown]
# #### Método isnull().sum() | Muestra el total de las columnas sin datos (nulos)

# %%
df.isnull().sum()
# Out:
# Edad                            0
# Renuncia                        1
# ViajesNegocios                  8
# TarifaDiaria                    0
# Departamento                    1
# DistanciaDesdeCasa              9
# NivelEducacion                  0
# Profesion                       5
# RecuentoEmpleados               1
# NumeroEmpleado                  0
# SatisfaccionAmbienteTrabajo     0
# Genero                          7
# TarifaPorHora                   0
# ParticipacionTrabajo            0
# NivelTrabajo                    0
# RolTrabajador                   2
# Satisfaccionlaboral             0
# EstadoCivil                    10
# IngresosMensuales               0
# TarifaMensual                   0
# NumeroEmpresasTrabajo           0
# MayorDe18                       0
# TiempoExtra                     8
# PorcentajeAumentoSalarial       0
# CalificacionRendimiento         0
# SatisfaccionRelacionLaboral     0
# HorasEstandar                   0
# ...

# %% [markdown]
# #### Método dropna() | Elimina cualquier fila con al menos un valor nulo, pero devolverá un nuevo DataFrame sin alterar el original

# %%
df2 = df.dropna()

# %% [markdown]
# #### dropna(axis=1) | Elimina columnas con valores nulos

# %%
df3 = df.dropna(axis=1)

# %% [markdown]
# #### Método fillna() | Reemplazar los valores nulos con datos (imputación)

# %%
# Extraemos los valores de las columnas en una variable
vColumnaDistanciaCasa = df['DistanciaDesdeCasa']

# %%
vColumnaDistanciaCasa.head
# Out:
# <bound method NDFrame.head of 0        1.0
# 1        8.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 1480     1.0
# 1481    11.0
# 1482     1.0
# 1483     9.0
# 1484     NaN
# Name: DistanciaDesdeCasa, Length: 1485, dtype: float64>

# %%
# Imputaremos asignando la media, para ello calculamos la media
ColumnaDistanciaCasaMedia = vColumnaDistanciaCasa.mean()
ColumnaDistanciaCasaMedia
# Out:
# 9.155149051490515

# %%
# Imputaremos asignando la media
vColumnaDistanciaCasa.fillna(ColumnaDistanciaCasaMedia, inplace=True)

# %%
# Extraemos los valores de las columnas en una variable
vcolumna = df['TiempoExtra']

# %%
vcolumna.head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# Name: TiempoExtra, dtype: object

# %%
# Asignamos valores a los datos vacios
vcolumna.fillna("Yes", inplace=True)

# %% [markdown]
# #### Método bfill() | Rellena los valores de Na/NaN utilizando el siguiente (hacia adelante) valor válido para rellenar el hueco

# %% [markdown]
# #### Método ffill() | Rellena los valores de Na/NaN utilizando el último (hacia atrás) valor válido para rellenar el hueco

# %% [markdown]
# ## Eliminar duplicados

# %% [markdown]
# #### Método duplicated()

# %% [markdown]
# Método drop_duplicates()
