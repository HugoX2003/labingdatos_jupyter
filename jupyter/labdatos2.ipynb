# %%
import pandas as pd

# %%
df_primaria = pd.read_csv('data/UNdata_Export_Primaria.csv')
df_primaria
# Out:
#                                     Area   Año NivelEducacion UnidadMedida  \
# 0                                Andorra  2014       Primaria      Percent
# 1                                Andorra  2013       Primaria      Percent
# 2                                Andorra  2011       Primaria      Percent
# 3                                Andorra  2010       Primaria      Percent
# 4                                Andorra  2009       Primaria      Percent
# ...                                  ...   ...            ...          ...
# 998   Venezuela (Bolivarian Republic of)  2006       Primaria      Percent
# 999                             Viet Nam  2010       Primaria      Percent
# 1000                              Zambia  2005       Primaria      Percent
# 1001                              Zambia  2004       Primaria      Percent
# 1002                            Zimbabwe  2010       Primaria      Percent
#
#       GastoEducacion
# 0           22.13474
# 1           32.11786
# ...

# %%
df_secundaria = pd.read_csv('data/UNdata_Export_Secundaria.csv')
df_secundaria
# Out:
#                                    Area   Año NivelEducacion UnidadMedida  \
# 0                               Andorra  2014     Secundaria      Percent
# 1                               Andorra  2013     Secundaria      Percent
# 2                               Andorra  2011     Secundaria      Percent
# 3                               Andorra  2010     Secundaria      Percent
# 4                               Andorra  2009     Secundaria      Percent
# ..                                  ...   ...            ...          ...
# 991  Venezuela (Bolivarian Republic of)  2006     Secundaria      Percent
# 992                            Viet Nam  2010     Secundaria      Percent
# 993                              Zambia  2005     Secundaria      Percent
# 994                              Zambia  2004     Secundaria      Percent
# 995                            Zimbabwe  2010     Secundaria      Percent
#
#      GastoEducacion
# 0          20.30919
# 1          35.23860
# ...

# %% [markdown]
# # Concatenación

# %%
pd.concat([df_primaria, df_secundaria])
# Out:
#                                    Area   Año NivelEducacion UnidadMedida  \
# 0                               Andorra  2014       Primaria      Percent
# 1                               Andorra  2013       Primaria      Percent
# 2                               Andorra  2011       Primaria      Percent
# 3                               Andorra  2010       Primaria      Percent
# 4                               Andorra  2009       Primaria      Percent
# ..                                  ...   ...            ...          ...
# 991  Venezuela (Bolivarian Republic of)  2006     Secundaria      Percent
# 992                            Viet Nam  2010     Secundaria      Percent
# 993                              Zambia  2005     Secundaria      Percent
# 994                              Zambia  2004     Secundaria      Percent
# 995                            Zimbabwe  2010     Secundaria      Percent
#
#      GastoEducacion
# 0          22.13474
# 1          32.11786
# ...

# %%
# A nivel de columna
pd.concat([df_primaria, df_secundaria], axis=1)
# Out:
#                                     Area   Año NivelEducacion UnidadMedida  \
# 0                                Andorra  2014       Primaria      Percent
# 1                                Andorra  2013       Primaria      Percent
# 2                                Andorra  2011       Primaria      Percent
# 3                                Andorra  2010       Primaria      Percent
# 4                                Andorra  2009       Primaria      Percent
# ...                                  ...   ...            ...          ...
# 998   Venezuela (Bolivarian Republic of)  2006       Primaria      Percent
# 999                             Viet Nam  2010       Primaria      Percent
# 1000                              Zambia  2005       Primaria      Percent
# 1001                              Zambia  2004       Primaria      Percent
# 1002                            Zimbabwe  2010       Primaria      Percent
#
#       GastoEducacion     Area     Año NivelEducacion UnidadMedida  \
# ...

# %% [markdown]
# ## Fusión - Unión (Join)

# %% [markdown]
# #### Método merge() | Permite realizar uniones entre dataframes tal y como se realizan en bases de datos.
